# %%
from packages import * 
from func import * 
import glob

# %% [markdown]
# ### Plot Results

# %%
os.chdir('realizations/net_realization_1')
file_list = glob.glob("*.csv")
os.chdir('../')
os.chdir('../')

path = "realizations_combined/"
os.mkdir(path)

for j in file_list:
    all_filenames = []
    for i in range(2):
        all_filenames.append('realizations/net_realization_'+ str(i+1)+"/"+j)
    combined_csv = pd.concat([pd.read_csv(f, header = None) for f in all_filenames])
    
    combined_csv.to_csv(path+j, header = None, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-3-191bacc02c92> in <module>
#       5
#       6 path = "realizations_combined/"
# ----> 7 os.mkdir(path)
#       8
#       9 for j in file_list:
#
# FileExistsError: [Errno 17] File exists: 'realizations_combined/'

# %%
df_A_phi0 = pd.read_csv(path+"results_betaA_phi0.csv", header = None)
df_B_phi0 = pd.read_csv(path+"results_betaB_phi0.csv", header = None)
df_A_phi2 = pd.read_csv(path+"results_betaA_phi2.csv", header = None)
df_B_phi2 = pd.read_csv(path+"results_betaB_phi2.csv", header = None)
df_A_phi4 = pd.read_csv(path+"results_betaA_phi4.csv", header = None)
df_B_phi4 = pd.read_csv(path+"results_betaB_phi4.csv", header = None)

df_A_phi0.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_B_phi0.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_A_phi2.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_B_phi2.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_A_phi4.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_B_phi4.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 

df_A_b2 = pd.read_csv(path+"results_betaA_b2.csv", header = None)
df_B_b2 = pd.read_csv(path+"results_betaB_b2.csv", header = None)
df_A_b5 = pd.read_csv(path+"results_betaA_b5.csv", header = None)
df_B_b5 = pd.read_csv(path+"results_betaB_b5.csv", header = None)
df_A_b8 = pd.read_csv(path+"results_betaA_b8.csv", header = None)
df_B_b8 = pd.read_csv(path+"results_betaB_b8.csv", header = None)

df_A_b2.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_B_b2.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_A_b5.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_B_b5.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_A_b8.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_B_b8.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 

df_A_ERER = pd.read_csv(path+"results_betaA_ERER.csv", header = None)
df_B_ERER = pd.read_csv(path+"results_betaB_ERER.csv", header = None)
df_A_ERSF = pd.read_csv(path+"results_betaA_ERSF.csv", header = None)
df_B_ERSF = pd.read_csv(path+"results_betaB_ERSF.csv", header = None)
df_A_SFER = pd.read_csv(path+"results_betaA_SFER.csv", header = None)
df_B_SFER = pd.read_csv(path+"results_betaB_SFER.csv", header = None)
df_A_SFSF = pd.read_csv(path+"results_betaA_SFSF.csv", header = None)
df_B_SFSF = pd.read_csv(path+"results_betaB_SFSF.csv", header = None)

df_A_ERER.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_B_ERER.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_A_ERSF.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_B_ERSF.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_A_SFER.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_B_SFER.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_A_SFSF.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"] 
df_B_SFSF.columns = ["index", "betaA", "betaB", "RA", "RB", "VB"]

# %%
df_A_phi0 = df_A_phi0.groupby(['index']).mean()
df_B_phi0 = df_B_phi0.groupby(['index']).mean()
df_A_phi2 = df_A_phi2.groupby(['index']).mean()
df_B_phi2 = df_B_phi2.groupby(['index']).mean()
df_A_phi4 = df_A_phi4.groupby(['index']).mean()
df_B_phi4 = df_B_phi4.groupby(['index']).mean()
df_A_b2   =   df_A_b2.groupby(['index']).mean()  
df_B_b2   =   df_B_b2.groupby(['index']).mean()  
df_A_b5   =   df_A_b5.groupby(['index']).mean()  
df_B_b5   =   df_B_b5.groupby(['index']).mean()  
df_A_b8   =   df_A_b8.groupby(['index']).mean()  
df_B_b8   =   df_B_b8.groupby(['index']).mean()  
df_A_ERER = df_A_ERER.groupby(['index']).mean()
df_B_ERER = df_B_ERER.groupby(['index']).mean()
df_A_ERSF = df_A_ERSF.groupby(['index']).mean()
df_B_ERSF = df_B_ERSF.groupby(['index']).mean()
df_A_SFER = df_A_SFER.groupby(['index']).mean()
df_B_SFER = df_B_SFER.groupby(['index']).mean()
df_A_SFSF = df_A_SFSF.groupby(['index']).mean()
df_B_SFSF = df_B_SFSF.groupby(['index']).mean()

# %% [markdown]
# ### Fig 3

# %%
rows, cols = 3, 2
fig, ax = plt.subplots(rows, cols,
                       #sharex='col', 
                       #sharey='row', 
                       figsize=(10,10))

ax[0,0].plot(df_A_phi0["betaA"], df_A_phi0["RA"], label = r"$\phi = 0$")
ax[0,0].plot(df_A_phi2["betaA"], df_A_phi2["RA"], label = r"$\phi = 2$")
ax[0,0].plot(df_A_phi4["betaA"], df_A_phi4["RA"], label = r"$\phi = 4$")

ax[1,0].plot(df_A_phi0["betaA"], df_A_phi0["RB"], label = r"$\phi = 0$")
ax[1,0].plot(df_A_phi2["betaA"], df_A_phi2["RB"], label = r"$\phi = 2$")
ax[1,0].plot(df_A_phi4["betaA"], df_A_phi4["RB"], label = r"$\phi = 4$")

ax[2,0].plot(df_A_phi0["betaA"], df_A_phi0["VB"], label = r"$\phi = 0$")
ax[2,0].plot(df_A_phi2["betaA"], df_A_phi2["VB"], label = r"$\phi = 2$")
ax[2,0].plot(df_A_phi4["betaA"], df_A_phi4["VB"], label = r"$\phi = 4$")

ax[0,1].plot(df_B_phi0["betaB"], df_B_phi0["RA"], label = r"$\phi = 0$")
ax[0,1].plot(df_B_phi2["betaB"], df_B_phi2["RA"], label = r"$\phi = 2$")
ax[0,1].plot(df_B_phi4["betaB"], df_B_phi4["RA"], label = r"$\phi = 4$")

ax[1,1].plot(df_B_phi0["betaB"], df_B_phi0["RB"], label = r"$\phi = 0$")
ax[1,1].plot(df_B_phi2["betaB"], df_B_phi2["RB"], label = r"$\phi = 2$")
ax[1,1].plot(df_B_phi4["betaB"], df_B_phi4["RB"], label = r"$\phi = 4$")

ax[2,1].plot(df_B_phi0["betaB"], df_B_phi0["VB"], label = r"$\phi = 0$")
ax[2,1].plot(df_B_phi2["betaB"], df_B_phi2["VB"], label = r"$\phi = 2$")
ax[2,1].plot(df_B_phi4["betaB"], df_B_phi4["VB"], label = r"$\phi = 4$")

#ax[0,0].set_ylim(0,1)
#ax[1,0].set_ylim(0,1)
#ax[2,0].set_ylim(0,1)

ax[0,0].grid(linestyle='--')
ax[1,0].grid(linestyle='--') 
ax[2,0].grid(linestyle='--')
ax[0,1].grid(linestyle='--')
ax[1,1].grid(linestyle='--') 
ax[2,1].grid(linestyle='--')

ax[0,0].legend()
ax[1,0].legend()
ax[2,0].legend()
ax[0,1].legend()
ax[1,1].legend()
ax[2,1].legend()

ax[0,0].text(x = 0.01, y = 0.98, s = "(a)", fontsize = 16)
ax[1,0].text(x = 0.01, y = 0.42, s = "(b)", fontsize = 16)
ax[2,0].text(x = 0.01, y = 0.30, s = "(c)", fontsize = 16)
ax[0,1].text(x = 0.01, y = 0.99, s = "(d)", fontsize = 16)
ax[1,1].text(x = 0.01, y = 0.85, s = "(e)", fontsize = 16)
ax[2,1].text(x = 0.01, y = 0.20, s = "(f)", fontsize = 16)

ax[2,0].set_xlabel(r"$\beta_A$", fontsize = 14)
ax[2,1].set_xlabel(r"$\beta_B$", fontsize = 14)

ax[0,0].set_ylabel(r"$R_A$", fontsize = 14)
ax[1,0].set_ylabel(r"$R_B$", fontsize = 14)
ax[2,0].set_ylabel(r"$V_B$", fontsize = 14)

plt.savefig("Fig3.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Fig 4

# %%
rows, cols = 3, 2
fig, ax = plt.subplots(rows, cols,
                       #sharex='col', 
                       #sharey='row', 
                       figsize=(10,10))

ax[0,0].plot(df_A_b2["betaA"], df_A_b2["RA"], label = r"$\beta_B = 0.05$")
ax[0,0].plot(df_A_b5["betaA"], df_A_b5["RA"], label = r"$\beta_B = 0.10$")
ax[0,0].plot(df_A_b8["betaA"], df_A_b8["RA"], label = r"$\beta_B = 0.15$")

ax[1,0].plot(df_A_b2["betaA"], df_A_b2["RB"], label = r"$\beta_B = 0.05$")
ax[1,0].plot(df_A_b5["betaA"], df_A_b5["RB"], label = r"$\beta_B = 0.10$")
ax[1,0].plot(df_A_b8["betaA"], df_A_b8["RB"], label = r"$\beta_B = 0.15$")

ax[2,0].plot(df_A_b2["betaA"], df_A_b2["VB"], label = r"$\beta_B = 0.05$")
ax[2,0].plot(df_A_b5["betaA"], df_A_b5["VB"], label = r"$\beta_B = 0.10$")
ax[2,0].plot(df_A_b8["betaA"], df_A_b8["VB"], label = r"$\beta_B = 0.15$")

ax[0,1].plot(df_B_b2["betaB"], df_B_b2["RA"], label = r"$\beta_A = 0.05$")
ax[0,1].plot(df_B_b5["betaB"], df_B_b5["RA"], label = r"$\beta_A = 0.10$")
ax[0,1].plot(df_B_b8["betaB"], df_B_b8["RA"], label = r"$\beta_A = 0.15$")

ax[1,1].plot(df_B_b2["betaB"], df_B_b2["RB"], label = r"$\beta_A = 0.05$")
ax[1,1].plot(df_B_b5["betaB"], df_B_b5["RB"], label = r"$\beta_A = 0.10$")
ax[1,1].plot(df_B_b8["betaB"], df_B_b8["RB"], label = r"$\beta_A = 0.15$")

ax[2,1].plot(df_B_b2["betaB"], df_B_b2["VB"], label = r"$\beta_A = 0.05$")
ax[2,1].plot(df_B_b5["betaB"], df_B_b5["VB"], label = r"$\beta_A = 0.10$")
ax[2,1].plot(df_B_b8["betaB"], df_B_b8["VB"], label = r"$\beta_A = 0.15$")

#ax[0,0].set_ylim(0,1)
#ax[1,0].set_ylim(0,1)
#ax[2,0].set_ylim(0,1)

ax[0,0].grid(linestyle='--')
ax[1,0].grid(linestyle='--') 
ax[2,0].grid(linestyle='--')
ax[0,1].grid(linestyle='--')
ax[1,1].grid(linestyle='--') 
ax[2,1].grid(linestyle='--')

ax[0,0].legend()
ax[1,0].legend()
ax[2,0].legend()
ax[0,1].legend()
ax[1,1].legend()
ax[2,1].legend()

ax[0,0].text(x = 0.01, y = 0.90, s = "(a)", fontsize = 16)
ax[1,0].text(x = 0.01, y = 0.75, s = "(b)", fontsize = 16)
ax[2,0].text(x = 0.01, y = 0.08, s = "(c)", fontsize = 16)
ax[0,1].text(x = 0.01, y = 0.80, s = "(d)", fontsize = 16)
ax[1,1].text(x = 0.01, y = 0.80, s = "(e)", fontsize = 16)
ax[2,1].text(x = 0.01, y = 0.08, s = "(f)", fontsize = 16)

ax[2,0].set_xlabel(r"$\beta_A$", fontsize = 14)
ax[2,1].set_xlabel(r"$\beta_B$", fontsize = 14)

ax[0,0].set_ylabel(r"$R_A$", fontsize = 14)
ax[1,0].set_ylabel(r"$R_B$", fontsize = 14)
ax[2,0].set_ylabel(r"$V_B$", fontsize = 14)

plt.savefig("Fig4.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Fig. 6

# %%
betaA_min = df_A_phi2.loc[df_A_phi2['RB'] == df_A_phi2['RB'].min(), 'betaA'].tolist()

print(betaA_min[0])
# Out:
# 0.06315789473684211

# %%
N, GA, GB, betaA, gammaA, betaB, gammaB, phi, p, t_max, niter = init() 
res5 = propagator_AB("c", GA, GB, betaA_min[0]-0.030, gammaA, 0.075, gammaB, 2, p, t_max)
res7 = propagator_AB("c", GA, GB, betaA_min[0], gammaA, 0.075, gammaB, 2, p, t_max)
res9 = propagator_AB("c", GA, GB, betaA_min[0]+0.030, gammaA, 0.075, gammaB, 2, p, t_max)

# %%
rows, cols = 3, 1
fig, ax = plt.subplots(rows, cols,
                       #sharex='col', 
                       #sharey='row', 
                       figsize=(10,10))

t = [i for i in range(len(res5[0]))]

ax[0].plot(t, res5[0], label = r"$\rho_{B}$")
ax[0].plot(t, res5[1], label = r"$\rho_{A}^{A}$")
ax[0].plot(t, res5[2], label = r"$\rho_{A}^{B}$")

ax[1].plot(t, res7[0], label = r"$\rho_{B}$")
ax[1].plot(t, res7[1], label = r"$\rho_{A}^{A}$")
ax[1].plot(t, res7[2], label = r"$\rho_{A}^{B}$")

ax[2].plot(t, res9[0], label = r"$\rho_{B}$")
ax[2].plot(t, res9[1], label = r"$\rho_{A}^{A}$")
ax[2].plot(t, res9[2], label = r"$\rho_{A}^{B}$")

ax[0].grid(linestyle='--')
ax[1].grid(linestyle='--') 
ax[2].grid(linestyle='--')

ax[0].legend()
ax[1].legend()
ax[2].legend()

ax[0].text(x = 0, y = 0.20, s = "(a)", fontsize = 16)
ax[1].text(x = 0, y = 0.20, s = "(b)", fontsize = 16)
ax[2].text(x = 0, y = 0.20, s = "(c)", fontsize = 16)


ax[2].set_xlabel(r"$t$", fontsize = 14)

ax[0].set_ylabel(r"$\rho$", fontsize = 14)
ax[1].set_ylabel(r"$\rho$", fontsize = 14)
ax[2].set_ylabel(r"$\rho$", fontsize = 14)

plt.savefig("Fig6.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Fig 8

# %%
rows, cols = 3, 2
fig, ax = plt.subplots(rows, cols,
                       #sharex='col', 
                       #sharey='row', 
                       figsize=(10,10))

ax[0,0].plot(df_A_ERER["betaA"], df_A_ERER["RA"], label = "ER-ER")
ax[0,0].plot(df_A_ERSF["betaA"], df_A_ERSF["RA"], label = "ER-SF")
ax[0,0].plot(df_A_SFER["betaA"], df_A_SFER["RA"], label = "SF-ER")
ax[0,0].plot(df_A_SFSF["betaA"], df_A_SFSF["RA"], label = "SF-SF")

ax[1,0].plot(df_A_ERER["betaA"], df_A_ERER["RB"], label = "ER-ER")
ax[1,0].plot(df_A_ERSF["betaA"], df_A_ERSF["RB"], label = "ER-SF")
ax[1,0].plot(df_A_SFER["betaA"], df_A_SFER["RB"], label = "SF-ER")
ax[1,0].plot(df_A_SFSF["betaA"], df_A_SFSF["RB"], label = "SF-SF")

ax[2,0].plot(df_A_ERER["betaA"], df_A_ERER["VB"], label = "ER-ER")
ax[2,0].plot(df_A_ERSF["betaA"], df_A_ERSF["VB"], label = "ER-SF")
ax[2,0].plot(df_A_SFER["betaA"], df_A_SFER["VB"], label = "SF-ER")
ax[2,0].plot(df_A_SFSF["betaA"], df_A_SFSF["VB"], label = "SF-SF")

ax[0,1].plot(df_B_ERER["betaB"], df_B_ERER["RA"], label = "ER-ER")
ax[0,1].plot(df_B_ERSF["betaB"], df_B_ERSF["RA"], label = "ER-SF")
ax[0,1].plot(df_B_SFER["betaB"], df_B_SFER["RA"], label = "SF-ER")
ax[0,1].plot(df_B_SFSF["betaB"], df_B_SFSF["RA"], label = "SF-SF")

ax[1,1].plot(df_B_ERER["betaB"], df_B_ERER["RB"], label = "ER-ER")
ax[1,1].plot(df_B_ERSF["betaB"], df_B_ERSF["RB"], label = "ER-SF")
ax[1,1].plot(df_B_SFER["betaB"], df_B_SFER["RB"], label = "SF-ER")
ax[1,1].plot(df_B_SFSF["betaB"], df_B_SFSF["RB"], label = "SF-SF")

ax[2,1].plot(df_B_ERER["betaB"], df_B_ERER["VB"], label = "ER-ER")
ax[2,1].plot(df_B_ERSF["betaB"], df_B_ERSF["VB"], label = "ER-SF")
ax[2,1].plot(df_B_SFER["betaB"], df_B_SFER["VB"], label = "SF-ER")
ax[2,1].plot(df_B_SFSF["betaB"], df_B_SFSF["VB"], label = "SF-SF")


#ax[0,0].set_ylim(0,1)
#ax[1,0].set_ylim(0,1)
#ax[2,0].set_ylim(0,1)

ax[0,0].grid(linestyle='--')
ax[1,0].grid(linestyle='--') 
ax[2,0].grid(linestyle='--')
ax[0,1].grid(linestyle='--')
ax[1,1].grid(linestyle='--') 
ax[2,1].grid(linestyle='--')

ax[0,0].legend()
ax[1,0].legend()
ax[2,0].legend()
ax[0,1].legend()
ax[1,1].legend()
ax[2,1].legend()

ax[0,0].text(x = 0.01, y = 0.975, s = "(a)", fontsize = 16)
ax[1,0].text(x = 0.01, y = 0.630, s = "(b)", fontsize = 16)
ax[2,0].text(x = 0.01, y = 0.060, s = "(c)", fontsize = 16)
ax[0,1].text(x = 0.01, y = 0.985, s = "(d)", fontsize = 16)
ax[1,1].text(x = 0.01, y = 0.800, s = "(e)", fontsize = 16)
ax[2,1].text(x = 0.01, y = 0.080, s = "(f)", fontsize = 16)

ax[2,0].set_xlabel(r"$\beta_A$", fontsize = 14)
ax[2,1].set_xlabel(r"$\beta_B$", fontsize = 14)

ax[0,0].set_ylabel(r"$R_A$", fontsize = 14)
ax[1,0].set_ylabel(r"$R_B$", fontsize = 14)
ax[2,0].set_ylabel(r"$V_B$", fontsize = 14)

plt.savefig("Fig8.pdf", bbox_inches='tight')

plt.show()
